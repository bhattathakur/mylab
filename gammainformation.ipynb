# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re
import csv
from io import StringIO
import json

# %%
url='https://www.nndc.bnl.gov/nudat2/decaysearchdirect.jsp?nuc={}&unc=nds'
#https://www.nndc.bnl.gov/nudat2/decaysearchdirect.jsp?nuc=133BA&unc=nds
#url='https://www.nndc.bnl.gov/nudat2/decaysearchdirect.jsp?nuc=241AM&unc=nds'
#url='https://www.nndc.bnl.gov/nudat2/decaysearchdirect.jsp?nuc=60CO&unc=nds'

# %%
#nuclei='241AM'  #nuclei of interst
nuclei=['241AM','133BA','60CO','137CS','152EU','22NA','210PB','226RA']

# %%
response=requests.get(url.format(nuclei[0]))            #request for a web page
soup=BeautifulSoup(response.text,'html.parser')         #creating the soup object with given page
table_tag=soup.find('table')
table_rows=table_tag.find_all('tr')
table_rows[1].find("td",class_="su")
desired=table_rows[2]
all_td=desired.find_all('td')
mass_no,atom_no=all_td[0].get_text(separator=" ").split()
symbol=all_td[1].get_text()
print("Our Symbol\n",mass_no+symbol+atom_no)
# Out:
# Our Symbol
#  241Am95

# %%
#soup.prettify()
utags=soup.find_all('u',text='Gamma and X-ray radiation')
for utag in utags:
    print(utag.text,"\n")
    #parent=utag.parent.parent
    #print("parent\t",utag.parent)
    print("next-sibling\n",utag.parent.next_sibling.text)
    #print("next-element\t",utag.next_element)
    #print("next-element with parent\t",parent.next_element.text)
# Out:
# Gamma and X-ray radiation
#
# next-sibling
#  Energy  (keV)Intensity  (%)Dose ( MeV/Bq-s )
# XR l    13.9      37 % 3   0.0051 5
#     26.3446 2        2.27 % 12   6.0E-4 3
#     33.196 1        0.126 % 3   4.18E-5 11
#     42.704 5        0.0055 % 11   2.3E-6 5
#     43.420 3        0.073 % 8   3.2E-5 3
#     51.01 3  S      2.6E-5 % 12   1.3E-8 6
#     55.56 2        0.0181 % 18   1.01E-5 10
#     59.5409 1       35.9 % 4   0.02138 22
#     64.83 2  S      1.45E-4 % 18   9.4E-8 12
#     67.45 5        4.2E-4 % 10   2.8E-7 7
#     69.76 3        0.0029 % 4   2.0E-6 3
#     75.8 2        5.9E-4 % 6   4.5E-7 4
# XR kα2    97.069       0.00114 % 4   1.10E-6 4
#     98.97 2        0.0203 % 4   2.01E-5 4
# XR kα1   101.059       0.00181 % 6   1.83E-6 6
#    102.98 2        0.0195 % 4   2.01E-5 5
#    109.70 7        4.90E-6 %  5.38E-9
# XR kβ3   113.303       2.27E-4 % 7   2.57E-7 8
# XR kβ1   114.234       4.30E-4 % 14   4.91E-7 16
# XR kβ2   117.463       1.68E-4 % 5   1.97E-7 6
#    120.36 8  ?      4.50E-6 %  5.42E-9
#    123.052 7        1.00E-3 % 3   1.23E-6 4
#    125.30 2        0.00408 % 10   5.11E-6 12
#    139.44 8        5.3E-6 % 11   7.4E-9 15
#    146.55 3        4.61E-4 % 12   6.76E-7 17
#    150.04 3        7.40E-5 % 22   1.11E-7 3
#    154.27 20        5.40E-7 %  8.33E-10
#    159.26 20        1.4E-6 % 5   2.2E-9 8
#    161.54 10        1.500E-6 %  2.423E-9
#    164.69 4        6.67E-5 % 25   1.10E-7 4
#    165.81 6        2.32E-5 % 11   3.85E-8 19
#    169.56 3        1.73E-4 % 4   2.93E-7 7
#    175.07 4        1.82E-5 % 10   3.19E-8 18
#    191.96 4        2.16E-5 % 10   4.15E-8 20
#    197.0 2        4.90E-7 %  9.65E-10
#    204.06 6        2.90E-6 % 19   5.9E-9 4
#    208.01 3        7.91E-4 % 19   1.65E-6 4
#    221.46 3        4.24E-5 % 11   9.39E-8 24
#    232.81 5        4.6E-6 % 3   1.08E-8 7
#    234.33       7E-7 % 3   1.5E-9 6
#    246.73 10        2.4E-6 % 3   6.0E-9 6
#    249.00 15        5.40E-7 %  1.345E-9
#    260.80 15        1.21E-6 % 19   3.2E-9 5
#    264.89 6        9.0E-6 % 4   2.38E-8 11
#    267.58 5        2.63E-5 % 8   7.04E-8 23
#    275.77 8        6.6E-6 % 4   1.82E-8 11
#    278.04 15        4.40E-7 %  1.223E-9
#    291.30 20        3.1E-6 % 3   9.0E-9 9
#    292.77 6        1.42E-5 % 5   4.16E-8 15
#    304.21 20        1.01E-6 % 21   3.1E-9 6
#    309.1 3        1.400E-6 %  4.33E-9
#    316.8 2  ?      3E-8 % 3   8E-11 8
#    322.52 3        1.52E-4 % 4   4.90E-7 11
#    332.35 3        1.49E-4 % 3   4.95E-7 11
#    335.37 3        4.96E-4 % 11   1.66E-6 4
#    337.7 2        4.29E-6 % 23   1.45E-8 8
#    358.25 20        1.20E-6 % 24   4.3E-9 9
#    368.65 3        2.17E-4 % 5   8.00E-7 20
#    370.94 3        5.23E-5 % 13   1.94E-7 5
#    376.65 3        1.38E-4 % 3   5.21E-7 12
#    383.81 3        2.82E-5 % 8   1.08E-7 3
#    398.64 15        2.000E-6 %  7.97E-9
#    401.3 30        4.90E-7 %  1.966E-9
#    406.35 15        1.45E-6 % 22   5.9E-9 9
#    419.33 4        2.87E-5 % 8   1.20E-7 4
#    426.47 4        2.46E-5 % 7   1.05E-7 3
#    446.43 15        4.90E-7 %  2.188E-9
#    452.6 2        2.4E-6 % 3   1.09E-8 11
#    454.66 8        9.7E-6 % 4   4.41E-8 19
#    459.68 10        3.6E-6 % 3   1.67E-8 13
#    463.22 20        1.000E-6 %  4.63E-9
#    468.12 15        2.88E-6 % 21   1.35E-8 10
#    487.3 3        4.40E-7 %  2.144E-9
#    512.5 3        1.15E-6 % 23   5.9E-9 12
#    514.0 5        2.6E-6 % 3   1.33E-8 14
#    522.06 15        1.0E-6 % 3   5.0E-9 15
#    529.17 20        4.60E-7 %  2.434E-9
#    545.4 3        7.40E-7 %  4.04E-9
#    563.05 30        7.40E-7 %  4.17E-9
#    573.94 20        1.25E-6 % 19   7.2E-9 11
#    586.59 20        1.31E-6 % 20   7.7E-9 12
#    590.28 15        2.86E-6 % 21   1.69E-8 13
#    597.48 8        7.4E-6 % 3   4.43E-8 20
#    619.01 2        5.94E-5 % 8   3.68E-7 5
#    627.18 20        5.6E-7 % 17   3.5E-9 11
#    632.93 15        1.26E-6 % 19   8.0E-9 12
#    641.47 5        7.1E-6 % 3   4.55E-8 20
#    653.02 4        3.77E-5 % 12   2.46E-7 8
#    662.40 2        3.64E-4 % 9   2.41E-6 6
#    666.5 3        4.90E-7 %  3.27E-9
#    669.83 20        3.8E-7 % 12   2.5E-9 8
#    676.03 30        6.4E-7 % 13   4.3E-9 9
#    680.10 10        3.13E-6 % 17   2.13E-8 12
#    688.72 4        3.25E-5 % 9   2.24E-7 6
#    696.60 5        5.34E-6 % 21   3.72E-8 14
#    722.01 3        1.96E-4 % 4   1.42E-6 3
#    729.72 15        1.33E-6 % 14   9.7E-9 10
#    737.34 5        8.0E-6 % 3   5.90E-8 19
#    755.90 5        7.6E-6 % 3   5.74E-8 22
#    767.00 10        5.00E-6 % 19   3.84E-8 14
#    770.57 10        4.74E-6 % 22   3.65E-8 17
#    772.4 3        2.66E-6 % 15   2.05E-8 12
#    786.00 15        6.20E-7 %  4.87E-9
#    801.94 20        1.36E-6 % 14   1.09E-8 11
#    806.26 30        3.10E-7 %  2.50E-9
#    828.5       2.4E-7 % 6   2.0E-9 5
#    860.7 5        8E-8 % 3   7.1E-10 22
#    862.7 5        5.3E-7 % 6   4.6E-9 5
#    887.3 3        2.2E-7 % 5   2.0E-9 4
#    921.5 3        1.9E-7 % 4   1.8E-9 4

# %%
#soup.prettify() #creates the nice print
#main_body=soup.body
table_tag=soup.find('table')
#all_p=main_body.find_all("p")
#len(all_p)  
#for i in range(len(all_p)):
 #   print(all_p[i].text)
#table_tag
table_rows=table_tag.find_all('tr')
# for i in table_rows:
#     print(120*".")
#     print(i)
#print("symbol in the table row")
table_rows[1].find("td",class_="su")
#print("sym\n",table_rows[2])
desired=table_rows[2]
all_td=desired.find_all('td')
# print("all_td\n",all_td)
# for i in all_td:
#     i.text
#     print()
# print(all_td[0].get_text(separator=" "))
mass_no,atom_no=all_td[0].get_text(separator=" ").split()
symbol=all_td[1].get_text()
# mass_no
# atom_no
# symbol
print("Our Symbol\n",mass_no+symbol+atom_no)
# Out:
# Our Symbol
#  60Co27

# %%
all_tables=soup.find_all('table')
# for i in range(len(all_tables)):
#     print("table {}....................".format(i))
#     #print(all_tables[i].prettify())
#     print(all_tables[i].text)
#len(all_tables)
gamma_table=all_tables[5]
print(gamma_table.text)
# Out:
# Parent  NucleusParent  E(level)Parent  JπParent  T1/2Decay Mode GS-GS Q-value  (keV) Daughter  NucleusDecayScheme ENSDFfile 6027Co  58.591     2+    10.467 m 6     β-: 0.25  3   %    2822.8 2    6028Ni

# %%
#find the name of the nuclei working with
table=soup.find('table',class_="W(100%)")
table_body=table.find('tbody')
table_data_row=table_body.find('tr')
table_data=table_data_row.find_all('td') #find all returns the list

#link="https://finance.yahoo.com"+href
#print(link)
tick_info=[]
for data in table_data[:-1]:
    #print("data\t",data)
    
    #print("data text\t",data.text)
    
    tick_info.append(data.text)
    #tikc_info.append(link)
href=table_data[0].find('a').get('href')
#href=data.find('a').get('href')
link="https://finance.yahoo.com"+href
tick_info.append(link)
print("link\t",link)
tick_info
# Out:
# link	 https://finance.yahoo.com/quote/LX?p=LX
# ['LX',
#  'LexinFintech Holdings Ltd.',
#  '11.70',
#  '+2.56',
#  '+28.01%',
#  '9.789M',
#  '1.371M',
#  '2.14B',
#  '23.83',
#  'https://finance.yahoo.com/quote/LX?p=LX']

# %%
#find the ticker block
table=soup.find('table',class_="W(100%)")
table_body=table.find('tbody')
table_data_row=table_body.find('tr')
table_data=table_data_row.find_all('td') #find all returns the list

#link="https://finance.yahoo.com"+href
#print(link)
tick_info=[]
for data in table_data[:-1]:
    #print("data\t",data)
    
    #print("data text\t",data.text)
    
    tick_info.append(data.text)
    #tikc_info.append(link)
href=table_data[0].find('a').get('href')
#href=data.find('a').get('href')
link="https://finance.yahoo.com"+href
tick_info.append(link)
print("link\t",link)
tick_info
# Out:
# link	 https://finance.yahoo.com/quote/LX?p=LX
# ['LX',
#  'LexinFintech Holdings Ltd.',
#  '11.70',
#  '+2.56',
#  '+28.01%',
#  '9.789M',
#  '1.371M',
#  '2.14B',
#  '23.83',
#  'https://finance.yahoo.com/quote/LX?p=LX']

# %%
# %%script false --no-raise-error #skip this cell and no error output
# #csv file to save the data
# csv_file=open("actives.csv","w")
# header=['Symbol','Name','Price','Change','%Change','Volume','Avg Vol(3 mo)','Market Cap','PE (TTM)'] #columns name
# csv_writer=csv.writer(csv_file)
# csv_writer.writerow(header)
# #find the ticker block
# table=soup.find('table',class_="W(100%)")
# table_body=table.find('tbody')
# table_data_rows=table_body.find_all('tr')    #get all the rows
# all_data=[]
# for row in table_data_rows:
#     table_data=row.find_all('td')[:-1] #find all returns the list
#     tick_info=[]
#     for data in table_data:
#         tick_info.append(data.text)
#     all_data.append(tick_info)
# #tick_info
# #all_data
# #len(all_data)
# #print(all_data[0])
# for i in range(len(all_data)):
#     print(all_data[i])
#     csv_writer.writerow(all_data[i])
# csv_file.close()

# %%
# %%script false --no-raise-error #skip this cell and no error output
# #most active data
# #csv file to save the data
# csv_file=open("actives.csv","w")
# header=['Symbol','Name','Price','Change','%Change','Volume','Avg Vol(3 mo)','Market Cap','PE (TTM)','Link'] #columns name
# csv_writer=csv.writer(csv_file)
# csv_writer.writerow(header)
# #find the ticker block
# table=soup.find('table',class_="W(100%)")
# table_body=table.find('tbody')
# table_data_rows=table_body.find_all('tr')    #get all the rows
# all_data=[]
# for row in table_data_rows:
#     table_data=row.find_all('td')[:-1] #find all returns the list
#     tick_info=[]
#     for data in table_data:
#         tick_info.append(data.text)
#     href=table_data[0].find('a').get('href')
#     link="https://finance.yahoo.com"+href
#     tick_info.append(link)
#     all_data.append(tick_info)
# #tick_info
# #all_data
# #len(all_data)
# #print(all_data[0])
# for i in range(len(all_data)):
#     print(all_data[i])
#     csv_writer.writerow(all_data[i])
# csv_file.close()

# %%
#csv file to save the data
csv_file=open("temp/gainers.csv","w")
header=['Symbol','Name','Price','Change','%Change','Volume','Avg Vol(3 mo)','Market Cap','PE (TTM)','Link'] #columns name
csv_writer=csv.writer(csv_file)
csv_writer.writerow(header)
#find the ticker block
table=soup.find('table',class_="W(100%)")
table_body=table.find('tbody')
table_data_rows=table_body.find_all('tr')    #get all the rows
all_data=[]
for row in table_data_rows:
    table_data=row.find_all('td')[:-1] #find all returns the list
    tick_info=[]
    for data in table_data:
        tick_info.append(data.text)
    href=table_data[0].find('a').get('href')
    link="https://finance.yahoo.com"+href
    tick_info.append(link)
    all_data.append(tick_info)
#tick_info
#all_data
#len(all_data)
#print(all_data[0])
for i in range(len(all_data)):
    print(all_data[i])
    csv_writer.writerow(all_data[i])
csv_file.close()
# Out:
# ['LX', 'LexinFintech Holdings Ltd.', '11.70', '+2.56', '+28.01%', '9.789M', '1.371M', '2.14B', '23.83', 'https://finance.yahoo.com/quote/LX?p=LX']
# ['CLDR', 'Cloudera, Inc.', '15.93', '+3.07', '+23.87%', '71.053M', '4.021M', '4.683B', 'N/A', 'https://finance.yahoo.com/quote/CLDR?p=CLDR']
# ['AMC', 'AMC Entertainment Holdings, Inc.', '32.04', '+5.92', '+22.66%', '474.803M', '106.648M', '14.427B', 'N/A', 'https://finance.yahoo.com/quote/AMC?p=AMC']
# ['QFIN', '360 DigiTech, Inc.', '33.76', '+5.69', '+20.27%', '7.519M', '2.746M', '5.145B', '7.20', 'https://finance.yahoo.com/quote/QFIN?p=QFIN']
# ['MPNGF', 'Meituan', '40.36', '+5.73', '+16.55%', '194,918', '77,056', '243.379B', '1,062.11', 'https://finance.yahoo.com/quote/MPNGF?p=MPNGF']
# ['AI', 'C3.ai, Inc.', '71.76', '+10.05', '+16.29%', '7.971M', '3.867M', '7.243B', 'N/A', 'https://finance.yahoo.com/quote/AI?p=AI']
# ['MVIS', 'MicroVision, Inc.', '17.95', '+2.35', '+15.06%', '19.732M', '25.84M', '2.835B', 'N/A', 'https://finance.yahoo.com/quote/MVIS?p=MVIS']
# ['YALA', 'Yalla Group Limited', '17.88', '+2.31', '+14.84%', '3.158M', '2.319M', '2.573B', 'N/A', 'https://finance.yahoo.com/quote/YALA?p=YALA']
# ['BB', 'BlackBerry Limited', '11.56', '+1.49', '+14.80%', '77.012M', '14.32M', '6.537B', 'N/A', 'https://finance.yahoo.com/quote/BB?p=BB']
# ['MPNGY', 'Meituan', '80.40', '+9.90', '+14.04%', '38,026', '70,020', '238.15B', '1,057.89', 'https://finance.yahoo.com/quote/MPNGY?p=MPNGY']
# ['DVN', 'Devon Energy Corporation', '30.20', '+3.64', '+13.70%', '37.231M', '11.329M', '20.442B', 'N/A', 'https://finance.yahoo.com/quote/DVN?p=DVN']
# ['MRO', 'Marathon Oil Corporation', '13.76', '+1.65', '+13.63%', '50.576M', '22.021M', '10.845B', 'N/A', 'https://finance.yahoo.com/quote/MRO?p=MRO']
# ['SM', 'SM Energy Company', '22.49', '+2.59', '+13.02%', '5.522M', '3.983M', '2.649B', 'N/A', 'https://finance.yahoo.com/quote/SM?p=SM']
# ['GME', 'GameStop Corp.', '249.02', '+27.02', '+12.17%', '9.427M', '15.444M', '17.624B', 'N/A', 'https://finance.yahoo.com/quote/GME?p=GME']
# ['EPR', 'EPR Properties', '54.98', '+5.83', '+11.86%', '1.655M', '613,284', '4.111B', 'N/A', 'https://finance.yahoo.com/quote/EPR?p=EPR']
# ['PDD', 'Pinduoduo Inc.', '139.34', '+14.46', '+11.58%', '20.519M', '7.747M', '174.633B', 'N/A', 'https://finance.yahoo.com/quote/PDD?p=PDD']
# ['SWN', 'Southwestern Energy Company', '5.75', '+0.58', '+11.22%', '20.89M', '15.231M', '3.892B', 'N/A', 'https://finance.yahoo.com/quote/SWN?p=SWN']
# ['APA', 'APA Corporation', '23.06', '+2.26', '+10.87%', '11.943M', '7.567M', '8.716B', '1,098.10', 'https://finance.yahoo.com/quote/APA?p=APA']
# ['CIOXY', 'Cielo S.A.', '0.8420', '+0.0818', '+10.75%', '1.483M', '192,210', '2.392B', '21.05', 'https://finance.yahoo.com/quote/CIOXY?p=CIOXY']
# ['UGP', 'Ultrapar Participações S.A.', '4.0600', '+0.3900', '+10.63%', '2.788M', '2.077M', '4.364B', '26.89', 'https://finance.yahoo.com/quote/UGP?p=UGP']
# ['CSAN', 'Cosan S.A.', '18.57', '+1.75', '+10.40%', '602,291', '536,837', '8.62B', 'N/A', 'https://finance.yahoo.com/quote/CSAN?p=CSAN']
# ['FINV', 'FinVolution Group', '8.30', '+0.78', '+10.37%', '2.559M', '3.656M', '2.352B', 'N/A', 'https://finance.yahoo.com/quote/FINV?p=FINV']
# ['GNENF', 'Ganfeng Lithium Co., Ltd.', '14.60', '+1.35', '+10.22%', '33,291', '60,265', '27.135B', '84.39', 'https://finance.yahoo.com/quote/GNENF?p=GNENF']
# ['BRFS', 'BRF S.A.', '5.43', '+0.50', '+10.14%', '13.723M', '4.272M', '4.386B', '15.83', 'https://finance.yahoo.com/quote/BRFS?p=BRFS']
# ['INCZY', 'Incitec Pivot Limited', '1.8700', '+0.1688', '+9.92%', '2.691M', '2,439', '3.818B', '49.21', 'https://finance.yahoo.com/quote/INCZY?p=INCZY']
# ['ETRN', 'Equitrans Midstream Corporation', '9.05', '+0.81', '+9.83%', '7.218M', '4.379M', '3.914B', '10.04', 'https://finance.yahoo.com/quote/ETRN?p=ETRN']
# ['AUOTY', 'AU Optronics Corp.', '9.43', '+0.84', '+9.78%', '215,699', '352,082', '8.855B', 'N/A', 'https://finance.yahoo.com/quote/AUOTY?p=AUOTY']
# ['TTUUF', 'Tokyu Fudosan Holdings Corporation', '6.19', '+0.55', '+9.75%', '72,132', '837', '4.765B', '22.59', 'https://finance.yahoo.com/quote/TTUUF?p=TTUUF']
# ['OXY', 'Occidental Petroleum Corporation', '28.47', '+2.51', '+9.67%', '27.333M', '18.247M', '26.574B', 'N/A', 'https://finance.yahoo.com/quote/OXY?p=OXY']
# ['NIO', 'NIO Inc.', '42.34', '+3.72', '+9.63%', '100.112M', '92.731M', '69.375B', 'N/A', 'https://finance.yahoo.com/quote/NIO?p=NIO']
# ['JMIA', 'Jumia Technologies AG', '31.98', '+2.79', '+9.56%', '4.786M', '7.326M', '3.153B', 'N/A', 'https://finance.yahoo.com/quote/JMIA?p=JMIA']
# ['MUR', 'Murphy Oil Corporation', '23.73', '+2.04', '+9.41%', '4.077M', '2.993M', '3.664B', 'N/A', 'https://finance.yahoo.com/quote/MUR?p=MUR']
# ['CCIV', 'Churchill Capital Corp IV', '21.56', '+1.84', '+9.33%', '22.297M', '19.978M', '5.579B', 'N/A', 'https://finance.yahoo.com/quote/CCIV?p=CCIV']
# ['OVV', 'Ovintiv Inc.', '29.11', '+2.48', '+9.31%', '4.312M', '2.718M', '7.609B', 'N/A', 'https://finance.yahoo.com/quote/OVV?p=OVV']
# ['CPG', 'Crescent Point Energy Corp.', '4.4700', '+0.3800', '+9.29%', '7.624M', '4.873M', '2.601B', 'N/A', 'https://finance.yahoo.com/quote/CPG?p=CPG']
# ['STEM', 'Stem, Inc.', '27.65', '+2.31', '+9.12%', '2.613M', '2.83M', '3.477B', 'N/A', 'https://finance.yahoo.com/quote/STEM?p=STEM']
# ['CVE', 'Cenovus Energy Inc.', '8.87', '+0.74', '+9.10%', '15.9M', '8.724M', '17.887B', 'N/A', 'https://finance.yahoo.com/quote/CVE?p=CVE']
# ['CRCT', 'Cricut, Inc.', '36.79', '+3.02', '+8.94%', '752,854', '774,413', '8.174B', 'N/A', 'https://finance.yahoo.com/quote/CRCT?p=CRCT']
# ['SPGYF', 'Whitecap Resources Inc.', '5.18', '+0.42', '+8.88%', '140,723', '66,839', '3.268B', '9.53', 'https://finance.yahoo.com/quote/SPGYF?p=SPGYF']
# ['RRC', 'Range Resources Corporation', '14.76', '+1.20', '+8.85%', '9.622M', '4.943M', '3.684B', 'N/A', 'https://finance.yahoo.com/quote/RRC?p=RRC']
# ['CLR', 'Continental Resources, Inc.', '35.44', '+2.87', '+8.81%', '2.926M', '2.071M', '13.025B', 'N/A', 'https://finance.yahoo.com/quote/CLR?p=CLR']
# ['TUYA', 'Tuya Inc.', '25.95', '+2.09', '+8.76%', '748,048', '1.449M', '14.526B', 'N/A', 'https://finance.yahoo.com/quote/TUYA?p=TUYA']
# ['MEOH', 'Methanex Corporation', '38.64', '+3.09', '+8.69%', '569,646', '300,709', '2.947B', 'N/A', 'https://finance.yahoo.com/quote/MEOH?p=MEOH']
# ['SBSW', 'Sibanye Stillwater Limited', '20.00', '+1.59', '+8.64%', '4.803M', '2.689M', '14.604B', 'N/A', 'https://finance.yahoo.com/quote/SBSW?p=SBSW']
# ['WXIBF', 'WuXi Biologics (Cayman) Inc.', '16.16', '+1.28', '+8.60%', '1.877M', '2,511', '67.812B', '256.51', 'https://finance.yahoo.com/quote/WXIBF?p=WXIBF']
# ['NBGIF', 'National Bank of Greece S.A.', '3.1700', '+0.2500', '+8.56%', '25,156', '13,517', '3.127B', '8.17', 'https://finance.yahoo.com/quote/NBGIF?p=NBGIF']
# ['SID', 'Companhia Siderúrgica Nacional', '9.23', '+0.70', '+8.21%', '3.721M', '4.328M', '12.685B', '6.42', 'https://finance.yahoo.com/quote/SID?p=SID']
# ['FANG', 'Diamondback Energy, Inc.', '86.61', '+6.54', '+8.17%', '4.178M', '2.762M', '15.676B', 'N/A', 'https://finance.yahoo.com/quote/FANG?p=FANG']
# ['RXRX', 'Recursion Pharmaceuticals, Inc.', '28.48', '+2.12', '+8.04%', '259,094', '657,696', '4.794B', 'N/A', 'https://finance.yahoo.com/quote/RXRX?p=RXRX']
# ['CPAMF', 'CapitaLand Integrated Commercial Trust', '1.6200', '+0.1200', '+8.00%', '24,223', '3,812', '10.815B', '25.71', 'https://finance.yahoo.com/quote/CPAMF?p=CPAMF']
# ['NUE', 'Nucor Corporation', '110.74', '+8.20', '+8.00%', '7.951M', '3.665M', '33.138B', '20.56', 'https://finance.yahoo.com/quote/NUE?p=NUE']
# ['API', 'Agora, Inc.', '48.23', '+3.54', '+7.92%', '1.475M', '1.246M', '5.588B', 'N/A', 'https://finance.yahoo.com/quote/API?p=API']
# ['LSRCY', 'Lasertec Corporation', '37.85', '+2.77', '+7.90%', '34,467', '190,583', '17.344B', 'N/A', 'https://finance.yahoo.com/quote/LSRCY?p=LSRCY']
# ['MEGEF', 'MEG Energy Corp.', '7.15', '+0.52', '+7.84%', '146,514', '79,637', '2.172B', 'N/A', 'https://finance.yahoo.com/quote/MEGEF?p=MEGEF']
# ['CNK', 'Cinemark Holdings, Inc.', '24.41', '+1.75', '+7.72%', '5.845M', '3.259M', '2.918B', 'N/A', 'https://finance.yahoo.com/quote/CNK?p=CNK']
# ['WXXWY', 'WuXi Biologics (Cayman) Inc.', '32.10', '+2.30', '+7.72%', '73,110', '139,307', '67.26B', '254.76', 'https://finance.yahoo.com/quote/WXXWY?p=WXXWY']
# ['XPEV', 'XPeng Inc.', '34.60', '+2.47', '+7.69%', '21.254M', '17.414M', '27.765B', 'N/A', 'https://finance.yahoo.com/quote/XPEV?p=XPEV']
# ['STOHF', 'Equinor ASA', '22.65', '+1.61', '+7.65%', '532,083', '49,482', '73.776B', 'N/A', 'https://finance.yahoo.com/quote/STOHF?p=STOHF']
# ['PDCE', 'PDC Energy, Inc.', '45.41', '+3.19', '+7.56%', '1.504M', '1.012M', '4.51B', 'N/A', 'https://finance.yahoo.com/quote/PDCE?p=PDCE']
# ['BABAF', 'Alibaba Group Holding Limited', '28.83', '+2.02', '+7.55%', '261,092', '31,090', '623.723B', 'N/A', 'https://finance.yahoo.com/quote/BABAF?p=BABAF']
# ['CX', 'CEMEX, S.A.B. de C.V.', '8.89', '+0.61', '+7.37%', '18.094M', '8.602M', '13.094B', 'N/A', 'https://finance.yahoo.com/quote/CX?p=CX']
# ['BYDDY', 'BYD Company Limited', '49.49', '+3.39', '+7.35%', '210,165', '255,671', '81.155B', '103.54', 'https://finance.yahoo.com/quote/BYDDY?p=BYDDY']
# ['BYDDF', 'BYD Company Limited', '24.68', '+1.68', '+7.30%', '199,289', '265,351', '81.117B', '103.26', 'https://finance.yahoo.com/quote/BYDDF?p=BYDDF']
# ['PETRY', 'Petrobras Distribuidora S.A.', '10.45', '+0.71', '+7.29%', '16,520', '19,524', '6.103B', 'N/A', 'https://finance.yahoo.com/quote/PETRY?p=PETRY']
# ['BZUN', 'Baozun Inc.', '37.18', '+2.49', '+7.18%', '1.109M', '796,123', '2.987B', '37.48', 'https://finance.yahoo.com/quote/BZUN?p=BZUN']
# ['IGMS', 'IGM Biosciences, Inc.', '79.99', '+5.34', '+7.15%', '195,979', '194,820', '2.562B', 'N/A', 'https://finance.yahoo.com/quote/IGMS?p=IGMS']
# ['RIG', 'Transocean Ltd.', '4.0500', '+0.2700', '+7.14%', '24.469M', '19.992M', '2.5B', 'N/A', 'https://finance.yahoo.com/quote/RIG?p=RIG']
# ['PREKF', 'PrairieSky Royalty Ltd.', '11.57', '+0.77', '+7.13%', '41,940', '16,639', '2.655B', '78.18', 'https://finance.yahoo.com/quote/PREKF?p=PREKF']
# ['DFH', 'Dream Finders Homes, Inc.', '34.00', '+2.23', '+7.02%', '429,493', '141,801', '3.146B', 'N/A', 'https://finance.yahoo.com/quote/DFH?p=DFH']
# ['DADA', 'Dada Nexus Limited', '26.88', '+1.75', '+6.96%', '1.521M', '1.337M', '6.336B', 'N/A', 'https://finance.yahoo.com/quote/DADA?p=DADA']
# ['REPYF', 'Repsol, S.A.', '13.95', '+0.90', '+6.90%', '47,490', '2,485', '22.319B', 'N/A', 'https://finance.yahoo.com/quote/REPYF?p=REPYF']
# ['AGL', 'agilon health, inc.', '38.40', '+2.46', '+6.84%', '446,484', '1.142M', '15.008B', 'N/A', 'https://finance.yahoo.com/quote/AGL?p=AGL']
# ['IPPLF', 'Inter Pipeline Ltd.', '15.62', '+0.99', '+6.77%', '51,824', '7,135', '6.704B', '20.37', 'https://finance.yahoo.com/quote/IPPLF?p=IPPLF']
# ['SSL', 'Sasol Limited', '17.46', '+1.10', '+6.72%', '581,014', '593,950', '10.955B', 'N/A', 'https://finance.yahoo.com/quote/SSL?p=SSL']
# ['PBF', 'PBF Energy Inc.', '17.22', '+1.08', '+6.69%', '3.545M', '3.398M', '2.07B', 'N/A', 'https://finance.yahoo.com/quote/PBF?p=PBF']
# ['POAHY', 'Porsche Automobil Holding SE', '11.81', '+0.73', '+6.62%', '1.179M', '1.157M', '36.366B', '8.43', 'https://finance.yahoo.com/quote/POAHY?p=POAHY']
# ['CHPT', 'ChargePoint Holdings, Inc.', '25.96', '+1.61', '+6.61%', '4.244M', '6.484M', '6.507B', 'N/A', 'https://finance.yahoo.com/quote/CHPT?p=CHPT']
# ['FTCH', 'Farfetch Limited', '49.37', '+3.04', '+6.56%', '8.61M', '8.908M', '17.515B', 'N/A', 'https://finance.yahoo.com/quote/FTCH?p=FTCH']
# ['MNSO', 'MINISO Group Holding Limited', '22.46', '+1.38', '+6.55%', '3.449M', '781,487', '6.827B', 'N/A', 'https://finance.yahoo.com/quote/MNSO?p=MNSO']
# ['MGY', 'Magnolia Oil & Gas Corporation', '13.76', '+0.84', '+6.50%', '3.178M', '2.006M', '3.332B', '28.43', 'https://finance.yahoo.com/quote/MGY?p=MGY']
# ['DCP', 'DCP Midstream, LP', '26.80', '+1.63', '+6.48%', '807,559', '810,787', '5.584B', '23.47', 'https://finance.yahoo.com/quote/DCP?p=DCP']
# ['HP', 'Helmerich & Payne, Inc.', '30.06', '+1.81', '+6.41%', '1.699M', '1.357M', '3.243B', 'N/A', 'https://finance.yahoo.com/quote/HP?p=HP']
# ['RLLCF', 'Rolls-Royce Holdings plc', '0.0153', '+0.0009', '+6.25%', '3.326M', '10.568M', '333.551B', 'N/A', 'https://finance.yahoo.com/quote/RLLCF?p=RLLCF']
# ['TIGR', 'UP Fintech Holding Limited', '24.21', '+1.42', '+6.23%', '8.374M', '8.995M', '3.441B', '91.70', 'https://finance.yahoo.com/quote/TIGR?p=TIGR']
# ['GLBE', 'Global-e Online Ltd.', '34.90', '+2.04', '+6.21%', '759,337', '1.536M', '4.964B', 'N/A', 'https://finance.yahoo.com/quote/GLBE?p=GLBE']
# ['DQ', 'Daqo New Energy Corp.', '78.95', '+4.57', '+6.14%', '3.755M', '2.705M', '5.804B', '33.40', 'https://finance.yahoo.com/quote/DQ?p=DQ']
# ['SU', 'Suncor Energy Inc.', '24.51', '+1.41', '+6.10%', '14.096M', '7.189M', '36.942B', '1,634.00', 'https://finance.yahoo.com/quote/SU?p=SU']
# ['PXD', 'Pioneer Natural Resources Company', '161.44', '+9.25', '+6.08%', '2.879M', '2.409M', '39.384B', 'N/A', 'https://finance.yahoo.com/quote/PXD?p=PXD']
# ['SAH', 'Sonic Automotive, Inc.', '51.16', '+2.93', '+6.08%', '281,981', '263,721', '2.128B', '10.82', 'https://finance.yahoo.com/quote/SAH?p=SAH']
# ['OTLY', 'Oatly Group AB', '25.15', '+1.44', '+6.07%', '6.66M', '11.982M', '14.892B', 'N/A', 'https://finance.yahoo.com/quote/OTLY?p=OTLY']
# ['ZY', 'Zymergen Inc.', '34.31', '+1.93', '+5.96%', '428,896', '680,103', '3.442B', 'N/A', 'https://finance.yahoo.com/quote/ZY?p=ZY']
# ['BFLY', 'Butterfly Network, Inc.', '12.45', '+0.70', '+5.96%', '3.318M', '2.955M', '2.382B', 'N/A', 'https://finance.yahoo.com/quote/BFLY?p=BFLY']
# ['BSBR', 'Banco Santander (Brasil) S.A.', '8.36', '+0.47', '+5.96%', '1.388M', '1.228M', '30.723B', '12.01', 'https://finance.yahoo.com/quote/BSBR?p=BSBR']
# ['PARXF', 'Parex Resources Inc.', '18.10', '+1.02', '+5.96%', '118,941', '8,293', '2.316B', '16.47', 'https://finance.yahoo.com/quote/PARXF?p=PARXF']
# ['RVLV', 'Revolve Group, Inc.', '58.74', '+3.30', '+5.95%', '877,762', '1.206M', '4.241B', 'N/A', 'https://finance.yahoo.com/quote/RVLV?p=RVLV']
# ['JD', 'JD.com, Inc.', '78.33', '+4.39', '+5.94%', '21.182M', '11.73M', '120.193B', '15.23', 'https://finance.yahoo.com/quote/JD?p=JD']
# ['BILI', 'Bilibili Inc.', '113.53', '+6.35', '+5.92%', '5.065M', '5.625M', '43.047B', 'N/A', 'https://finance.yahoo.com/quote/BILI?p=BILI']
# ['GGB', 'Gerdau S.A.', '6.62', '+0.37', '+5.92%', '12.905M', '19.89M', '11.289B', '12.90', 'https://finance.yahoo.com/quote/GGB?p=GGB']
# ['CCJ', 'Cameco Corporation', '21.14', '+1.17', '+5.86%', '9.653M', '5.625M', '8.407B', 'N/A', 'https://finance.yahoo.com/quote/CCJ?p=CCJ']
# ['NTCO', 'Natura &Co Holding S.A.', '20.69', '+1.14', '+5.83%', '1.057M', '458,271', '14.194B', 'N/A', 'https://finance.yahoo.com/quote/NTCO?p=NTCO']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#make clickable link for the column

def make_clickable(val):
    return '<a target ="_blank" href="{}">{}</a>'.format(val,"link")
    #target="_blank" opens the window to new window
    #can use val inplace to "link" to print the exact link

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'green'
    return 'color: %s' % color

# %%
def change_volume(v):
    '''
    Changes the volume into million if not already so.
    '''
    if v[-1] not in ['M','B']:
        if ',' in v:
            idx=v.find(',') 
            v=v[:idx]+v[idx+1:]
        sub=v[:-1]
        sub=float(sub)/10**6
        sub=str(sub)+'M'
    else:sub=v
    return sub

# %%
test='100,01'
change_volume(test)
# Out:
# '0.001M'

# %%
#df_actives=pd.read_csv('actives.csv')
df_losers=pd.read_csv('temp/gainers.csv')
df_losers.head()
#df_losers.style.format({'Link':make_clickable},{'Change':color_negative_red})#column names and formatting as the dictonary
#df_losers
df_losers['Volume']=df_losers['Volume'].apply(change_volume)
df_losers['Avg Vol(3 mo)']=df_losers['Avg Vol(3 mo)'].apply(change_volume)
df_losers=df_losers.style.\
applymap(color_negative_red,subset=['Change']).\
format({'Link':make_clickable}).\
format({'Price':"{:.2f}"}).\
format({'Change':"{:.2f}"})

# %%
df_losers.columns
# Out:
# Index(['Symbol', 'Name', 'Price', 'Change', '%Change', 'Volume',
#        'Avg Vol(3 mo)', 'Market Cap', 'PE (TTM)', 'Link'],
#       dtype='object')

# %%
df_losers
# Out:
# <style  type="text/css" >
#     #T_4d74a398_c324_11eb_8c88_93098362f81frow0_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow1_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow2_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow3_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow4_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow5_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow6_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow7_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow8_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow9_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow10_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow11_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow12_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow13_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow14_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow15_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow16_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow17_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow18_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow19_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow20_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow21_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow22_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow23_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow24_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow25_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow26_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow27_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow28_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow29_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow30_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow31_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow32_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow33_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow34_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow35_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow36_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow37_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow38_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow39_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow40_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow41_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow42_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow43_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow44_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow45_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow46_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow47_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow48_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow49_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow50_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow51_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow52_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow53_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow54_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow55_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow56_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow57_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow58_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow59_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow60_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow61_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow62_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow63_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow64_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow65_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow66_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow67_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow68_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow69_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow70_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow71_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow72_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow73_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow74_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow75_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow76_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow77_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow78_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow79_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow80_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow81_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow82_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow83_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow84_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow85_col3 {
#             color:  green;
#         }    #T_4d74a398_c324_11eb_8c88_93098362f81frow86_col3 {
#             colo

# %%
#data types of the data-frame
#df_losers.dtypes
#df_losers.style.applymap(color_negative_red,subset=['Change'])
#builtin method to give color to the null values
#https://mode.com/example-gallery/python_dataframe_styling/ example
#df_losers.style.highlight_null(null_color='re')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-83addf3c895d> in <module>
#       1 #data types of the data-frame
#       2 #df_losers.dtypes
# ----> 3 df_losers.style.applymap(color_negative_red,subset=['Change'])
#       4 #builtin method to give color to the null values
#       5 #https://mode.com/example-gallery/python_dataframe_styling/ example
#
# AttributeError: 'Styler' object has no attribute 'style'

# %%
df_gainers=df_gainers.style.format({'Link':make_clickable})#column names and formatting as the dictonary
df_gainers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a1c901a78d20> in <module>
# ----> 1 df_gainers=df_gainers.style.format({'Link':make_clickable})#column names and formatting as the dictonary
#       2 df_gainers
#
# NameError: name 'df_gainers' is not defined

# %%
#df_actives=df_actives.style.format({'Link':make_clickable})#column names and formatting as the dictonary
#df_actives=df_actives.style.format({'Change':color_tick_red})
#df_actives
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-184-ed8be753534c> in <module>
# ----> 1 df_actives=df_actives.style.format({'Link':make_clickable})#column names and formatting as the dictonary
#       2 df_actives=df_actives.style.format({'Change':color_tick_red})
#       3 df_actives
#
# AttributeError: 'Styler' object has no attribute 'style'

# %%
df_actives.format("{:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/lib/python3/dist-packages/pandas/io/formats/style.py in _repr_html_(self)
#     162         Hooks into Jupyter notebook rich display system.
#     163         """
# --> 164         return self.render()
#     165
#     166     @Appender(
#
# /usr/lib/python3/dist-packages/pandas/io/formats/style.py in render(self, **kwargs)
#     518         self._compute()
#     519         # TODO: namespace all the pandas keys
# --> 520         d = self._translate()
#     521         # filter out empty styles, every cell will have a class
#     522         # but the list of props may just be [['', '']].
#
# /usr/lib/python3/dist-packages/pandas/io/formats/style.py in _translate(self)
#     369                     "value": value,
#     370                     "class": " ".join(cs),
# --> 371                     "display_value": formatter(value),
#     372                     "is_visible": (c not in hidden_columns),
#     373                 }
#
# /usr/lib/python3/dist-packages/pandas/io/formats/style.py in <lambda>(x)
#    1464 def _maybe_wrap_formatter(formatter):
#    1465     if is_string_like(formatter):
# -> 1466         return lambda x: formatter.format(x)
#    1467     elif callable(formatter):
#    1468         return formatter
#
# ValueError: Unknown format code 'f' for object of type 'str'

# %%
#%%script false --no-raise-error #skip this cell and no error output
#ticker='NIO'
def color_tick_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for given value
    strings, black otherwise.
    """
    color = 'red' if val <0 else 'black'
    return 'color: %s' % color

#s = df_most_active.style.applymap(color_tick_red)
#s

# %%
df_actives.style#.apply(color_tick_red,subset=['Change'])
# Out:
# <style  type="text/css" >
# </style><table id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Symbol</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Change</th>        <th class="col_heading level0 col4" >%Change</th>        <th class="col_heading level0 col5" >Volume</th>        <th class="col_heading level0 col6" >Avg Vol(3 mo)</th>        <th class="col_heading level0 col7" >Market Cap</th>        <th class="col_heading level0 col8" >PE (TTM)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row0_col0" class="data row0 col0" >AMC</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row0_col1" class="data row0 col1" >AMC Entertainment Holdings, Inc.</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row0_col2" class="data row0 col2" >26.12</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row0_col3" class="data row0 col3" >-0.4</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row0_col4" class="data row0 col4" >-1.51%</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row0_col5" class="data row0 col5" >653.234M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row0_col6" class="data row0 col6" >106.648M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row0_col7" class="data row0 col7" >11.761B</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row0_col8" class="data row0 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row1_col0" class="data row1 col0" >F</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row1_col1" class="data row1 col1" >Ford Motor Company</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row1_col2" class="data row1 col2" >14.53</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row1_col3" class="data row1 col3" >-0.35</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row1_col4" class="data row1 col4" >-2.35%</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row1_col5" class="data row1 col5" >150.622M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row1_col6" class="data row1 col6" >77.072M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row1_col7" class="data row1 col7" >57.999B</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row1_col8" class="data row1 col8" >14.62</td>
#             </tr>
#             <tr>
#                         <th id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row2_col0" class="data row2 col0" >BB</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row2_col1" class="data row2 col1" >BlackBerry Limited</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row2_col2" class="data row2 col2" >10.07</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row2_col3" class="data row2 col3" >0.1</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row2_col4" class="data row2 col4" >+1.00%</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row2_col5" class="data row2 col5" >115.806M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row2_col6" class="data row2 col6" >14.32M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row2_col7" class="data row2 col7" >5.619B</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row2_col8" class="data row2 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row3_col0" class="data row3 col0" >PLTR</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row3_col1" class="data row3 col1" >Palantir Technologies Inc.</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row3_col2" class="data row3 col2" >22.95</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row3_col3" class="data row3 col3" >0.25</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row3_col4" class="data row3 col4" >+1.10%</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row3_col5" class="data row3 col5" >111.25M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row3_col6" class="data row3 col6" >66.59M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row3_col7" class="data row3 col7" >43.071B</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row3_col8" class="data row3 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row4_col0" class="data row4 col0" >GE</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row4_col1" class="data row4 col1" >General Electric Company</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row4_col2" class="data row4 col2" >14.06</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row4_col3" class="data row4 col3" >-0.29</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row4_col4" class="data row4 col4" >-2.02%</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row4_col5" class="data row4 col5" >72.572M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row4_col6" class="data row4 col6" >76.321M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row4_col7" class="data row4 col7" >123.428B</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row4_col8" class="data row4 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row5_col0" class="data row5 col0" >AAPL</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row5_col1" class="data row5 col1" >Apple Inc.</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row5_col2" class="data row5 col2" >124.61</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row5_col3" class="data row5 col3" >-0.67</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row5_col4" class="data row5 col4" >-0.53%</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row5_col5" class="data row5 col5" >71.311M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row5_col6" class="data row5 col6" >97.683M</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row5_col7" class="data row5 col7" >2.079T</td>
#                         <td id="T_470ac8aa_c0ec_11eb_b144_2733ab0b66c1row5_col8" class="data row5 col8" >28.01</td>

# %% [markdown]
# # Use Line wrap to see all the lines
# # /* -- Data -- */ includes the data

# %%
#getting the pattern with regular expression
pattern=re.compile(r'\s--\sData\s--\s') #\s->space
script_data=soup.find('script',text=pattern).contents[0]

# %%
script_data[:500]
# Out:
# '\n(function (root) {\n/* -- Data -- */\nroot.App || (root.App = {});\nroot.App.now = 1622305627282;\nroot.App.main = {"context":{"dispatcher":{"stores":{"PageStore":{"currentPageName":"quote","currentEvent":{"eventName":"NEW_PAGE_SUCCESS"},"currentRenderTargetId":"default","pagesConfigRaw":{"base":{"quote":{"layout":{"bundleName":"yahoodotcom-layout.TwoColumnLayout","name":"TwoColumnLayout","config":{"enableHeaderCollapse":true,"additionalBodyWrapperClasses":"Bgc($layoutBgColor)!","contentWrapperClas'

# %%
script_data[-500:]
# Out:
# 'put":{"strings":1},"tdv2-applet-sponsored-moments":{"strings":1},"tdv2-applet-stream":{"strings":1},"tdv2-applet-stream-hero":{"strings":1},"tdv2-applet-swisschamp":{"strings":1},"tdv2-applet-uh":{"strings":1},"tdv2-applet-userintent":{"strings":1},"tdv2-applet-video-lightbox":{"strings":1},"tdv2-applet-video-modal":{"strings":1},"tdv2-wafer-adfeedback":{"strings":1},"tdv2-wafer-header":{"strings":1},"yahoodotcom-layout":{"strings":1}}},"options":{"defaultBundle":"td-app-finance"}}}};\n}(this));\n'

# %%
#Extracting the json data from the text 
start=script_data.find("context")-2 # first { positon
json_data=json.loads(script_data[start:-12]) # {  is last 12 characters from the back
#json loads gives python dictionary

# %%
json_data['context'].keys()
# Out:
# dict_keys(['dispatcher', 'options', 'plugins'])

# %%
link='https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation='
html_text=requests.get(link).text
soup=BeautifulSoup(html_text,'lxml')
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx') #find first occurance

# %%
for job in jobs:
    date_published=job.find('span',class_="sim-posted").span.text
    #print(date_published)
    if 'few' in date_published:
        company_name=job.find('h3',class_="joblist-comp-name").text.replace(" ","")
        #print(jobs)<span class="srp-skills">
        #skills=job.find('span', class_="srp-skills")
        #print(skills)
        #print(company_name)
        skills=job.find('span', class_="srp-skills").text.replace(" ","")
        more_info=job.header.h2.a['href']


        #print(skills)
        #print(company_name)
        print(f'''
        Company Name: {company_name.strip()}
        Required Skills:{skills.strip()}
        More_Information:{more_info}
          '''
        )
        print()
# Out:
#         Company Name: Larsen&ToubroInfotechLtd
#         Required Skills:python,bi,sql,visualstudio,database,ssrs
#         More_Information:https://www.timesjobs.com/job-detail/python-larsen-toubro-infotech-ltd-mumbai-5-to-8-yrs-jobid-q4sK4bnqVzxzpSvf__PLUS__uAgZw==&source=srp
#
#
#
#         Company Name: SuryaInformaticsSolutionsPvt.Ltd.
#         Required Skills:python,webtechnologies,linux,mobile,mysql,angularjs,javascript
#         More_Information:https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
#
#
#
#         Company Name: TECHNOPARKTRIVANDRUM
#         Required Skills:python,django,understandingofDjango
#         More_Information:https://www.timesjobs.com/job-detail/python-developer-technopark-trivandrum-cochin-kochi-ernakulam-3-to-5-yrs-jobid-xGzuKVJAXMZzpSvf__PLUS__uAgZw==&source=srp
#
#
#
#         Company Name: MUVI.com
#         Required Skills:algorithms,python,machinelearning
#         More_Information:https://www.timesjobs.com/job-detail/python-developer-muvi-com-bhubaneshwar-0-to-3-yrs-jobid-Iz__PLUS__Cib9eEqlzpSvf__PLUS__uAgZw==&source=srp
#
#
#
#         Company Name: MOUNTTALENTCONSULTING
#         Required Skills:python,oops,softwaredeveloper
#         More_Information:https://www.timesjobs.com/job-detail/python-developer-mount-talent-consulting-bengaluru-bangalore-4-to-8-yrs-jobid-MNhENmBr5Q5zpSvf__PLUS__uAgZw==&source=srp
#
#
#
#         Company Name: TandAHRSolutions
#         Required Skills:python,git,django
#         More_Information:https://www.timesjobs.com/job-detail/python-developer-tanda-hr-solutions-chandigarh-5-to-8-yrs-jobid-id252yPhiLZzpSvf__PLUS__uAgZw==&source=srp
#
#
#
#         Company Name: RandstadMENA
#         Required Skills:python,c,oracle,database
#         More_Information:https://www.timesjobs.com/job-detail/python-testing-randstad-mena-bengaluru-bangalore-0-to-3-yrs-jobid-eOL1rxDnGktzpSvf__PLUS__uAgZw==&source=srp
#
#
#
#         Company Name: TandAHRSolutions
#         Required Skills:python,git,django
#         More_Information:https://www.timesjobs.com/job-detail/python-developers-tanda-hr-solutions-chandigarh-2-to-5-yrs-jobid-OtVSvO0kmYNzpSvf__PLUS__uAgZw==&source=srp
#
#
#
#         Company Name: JobsLoConsultants
#         Required Skills:python,linux,windows,sql
#         More_Information:https://www.timesjobs.com/job-detail/python-developer-jobslo-consultants-indore-2-to-3-yrs-jobid-XP1detWpoa5zpSvf__PLUS__uAgZw==&source=srp
#
#
#
#         Company Name: 3RITechnologiesPvtLtd
#         Required Skills:python,database,teamplayer
#         More_Information:https://www.timesjobs.com/job-detail/python-engineers-3ri-technologies-pvt-ltd-pune-0-to-3-yrs-jobid-vlvpVUMEBbxzpSvf__PLUS__uAgZw==&source=srp

# %%
print(html_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <head>
#
#
#
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"2aa1afabd7",applicationID:"57254935"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){d("pageHide",[p.now(),t])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}e.exports={agent:i,version:o,match:r}},{}],7:[function(t,e,n){function r(t){function e(){t(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventListener"in d ...
# 		<link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.8" rel="stylesheet" type="text/css" media="all"/>
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.8" rel="stylesheet" type="text/css" media="all"/>
#        <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.8" rel="stylesheet" type="text/css" media="all"/>
#       	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js"></script>
# 		<!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.8"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js"></script>
#
#
#         <link rel="canonical" href="https://www.timesjobs.com/candidate/job-search.html"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 						<link rel="next" href="https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=/&sequence=2&startPage=1"/>
#
#
#
#
#
#
#
#
#
# 				<title>python Jobs - TimesJobs</title>
#
#
#
#
# 			<meta name="description" content="Jobs in python. Search and apply jobs online at Timesjobs.com"/>
#
#
# 		<!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#         <script>
#           //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#         </script>
#
# </head>
#   	<body>
#   		<div id="site">
#
#
# 				<!-- Header Starts -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# 	<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4"
# 		height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
#
# <script type="text/javascript" src='https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js' ></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<div id="fb_connect_suggest" style="display: none;" class="msg notify">
# 		Dear Jobseeker, Find millions of jobs on single click.
# 		<span id="fb_auto_connect"><a href="javascript:fconnect_auto();"><img src='https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png' alt='fconnect'></a></span>
# 		<span class="big-cls cls-icn" title="Click to Hide" onclick="javascript:ack_fbconnect_cancel();"><i class="material-icons">close</i></span>
# 		<span id="fb_connect_status"></span>
# 		</div>
# 		<div id="fb_connect_success" style="display: none;" class="msg success">
# 			Congratulations! You have been logged in via Facebook
# 		</div>
#
#
#
#
# <header class="main-header">
# <div class="top-header">
# 	<div class="ubility-wrap clearfix">
# <ul class="top-link">
#     <li><a href="https://www.timesjobs.com" class="link-active">TimesJobs</a></li>
#     <li><a href="http://jobbuzz.timesjobs.com" target="_blank">JobBuzz</a></li>
#     <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
#     <li><a href="https://ae.timesjobs.com" target="_blank">Gulf Jobs</a></li>
#     <li><a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">Career Insight</a></li>
#   </ul>
#
# <ul class="top-contact">
# 	 <li><i class="material-icons">call</i>0120 6358222</li>
#     <li>
#
#        	   <span id="chat-widget" class="live-chat">Live Chat (10am to 6pm IST)</span>
#
#     </li>
# 	</ul>
# 	</div>
# 	</div>
# 	<div class="ubility-wrap logo-section clearfix">
#
#
#
#
#
#
# 		<a itemprop="url" title="TIMESJOBS" href="https://www.timesjobs.com" class="top-tj-logo">
# 			<img src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" alt="TimesJobs" width="140" height="23" title="TimesJobs" itemprop="logo">
# 		</a>
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="career-affection" class="career-affection top-notifi notify-msg covid-home-page" style="display:none">
# 		<div class="career-affection-inner wrap career-effect" id="career-affection-inner ">
# 			Is your career affected by Covid-19?
# 			<a href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('Y','TJWEB');" class="yes-button">Yes</a> <a
# 				href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('N','TJWEB');" class="no-button">No</a>
# 		</div>
# 	</div>
#
#
#
#
#
#
#
#
#
#
# 			<script type="text/javascript">
# 				jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
# 			</script>
#
#
#
#
#
#
#
# 	  <ul class="main-tj-nav clearfix">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#
# </script>
# <!--- view notification section begin --->
#  <li class="notification viewnote">
# 	<a class='dropdown-button' href='#' data-activates='notifyDropdown'>
# 		<i class="material-icons left">notifications_none</i>
# 		<span id="notification_count" class="notif-count-new">1</span>&nbsp;
# 	</a>
# 	<div class="nav-drop viewnoteTab dropdown-content" id='notifyDropdown'>
# 	<div class="showdiv">
# 		<div id="non_loggedin" class="notif-not-logedin" style="display:none;">
# 			<div class="notif-welcm-msg clearfix">To see all recommended jobs, profile views, recruiter's contacted information, updates and more...</div>
# 	 			<div class='notif-act clearfix'>
#
#
#
# 						<button type='button' class='waves-effect waves-light btn red-bdr-btn' onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</button>
#
#
# 				<strong class='or'>or</strong>
# 				<a href="/candidate/register.html" class='waves-effect waves-light btn red-bdr-btn' >Register</a>
# 	    	</div>
# 	   	</div>
#
#
#
# 		<!-- INLINE LOGIN PAGE -->
#
# 		<div id="inline_login" class="notif-login-frm" style="display:none;">
#         <span class="notif-cls" title="Click to Hide"></span>
#
#
#
# 			  <strong>Login to View Notifications!</strong>
#
#
# 		<form action="/candidate/times_login?BeforeLoginUrl=notification&tab=1" method="post" name="loginFormNotification">
#
#
#
#
# 				    <input name="j_username" id="txtUseNameNotification" type="text" onblur="javascript:settextNotification('txtUseNameNotification');" onClick="filltxtNotification(txtUseNameNotification)" value="Enter Email id / Login id" class="txt2 defaultValue inpt-typ" size="42" />
#
#
# 		    <input name="j_password" type="password" value="" class="password_input_notification" size="42"  style="display:none" />
#             <input type="text" value="Enter Password" class="clearNotification" size="42" />
#             <div class="frgt-pass"><a href="javascript:forgotPasswordNotification();" class="fp">Forgot Password?</a></div>
#
# 	      <input class="" type="submit" onClick="javascript:return validateLoginFormNotification();" value="Login" />
#
#           <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
#            	      <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
#                   <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#        	      Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
# 	      </div>
#
#   	    <input type="hidden" name="notlogin" value="mytj">
# 		  <input type="hidden" name="_acegi_security_remember_me" value="yes">
# 	    </form>
# 	    </div>
#
# 		<!-- INLINE LOGIN PAGE -->
#                        <div id="base" style="display: none;" class="notif-main">
# 						   <ul>
# 	                       	   <li id="heading" class="heading clearfix">
# 	                       	   	<a id="heading-link" href="#"><span>Job Alerts(10)</span></a>
# 	                       	   </li>
# 		                       		<li id="base-li" style="display: none;"><a id="base-li-anchor" href="#">5 Matching Jobs <span id="base-li-time">3 hrs ago</span></a>
# 		                       		</li>
# 		                       		<span id="base-li-data" style="display: none;"  class="base_li"></span>
# 		                       </ul>
#                        </div>
#                        </div>
#           </div>
# 	  	  </li>
#
#                     <!--- view notification section ends here --->
#
#
# 	<script type="text/javascript">
#
# function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1622221206-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#
# </script>
#
#
#
#
#
#
#
#
#
# 				<li class="login-reg">
# 					<a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</a>
# 				</li>
#
#
# 		<li class="login-reg">
#
# 				<a href="/candidate/register.html?pageFlow=TJ_SEARCH">Register</a>
#
#
# 		</li>
#
# 	</ul>
#
#
# 	</div>
# </header>
# 	<!--bottom banner starts-->
#
#           <!--bottom banner ends-->
#
#
#
#
#
# 			<div class="open-search ">
#
#
#
#
#
#
# <div class="usability-srch clearfix">
#   <div class="main-srch-form clearfix">
# 	  <div id="errorMsgDiv" class="msg error" style="display:none">Please provide inputs for at least one field</div>
#        <form id="quickSearchBean" name="quickSearchBean" action="https://www.timesjobs.com/candidate/job-search.html" method="get"  onSubmit="return searchEngine.validateSearchForm(this);" >
#
#           	<input name="searchType" value="personalizedSearch" type="hidden">
#           	<input name="from" value="submit" type="hidden">
#           	<div class="auto-suggest-blk">
#
#
#
#
#             <input id="txtKeywords" name="txtKeywords" type="text"  value="python" class="browser-default"/>
#             <div id="autoSuggestList" style="display:none;"><ul></ul></div><iframe id="FrameautoSuggestList" frameborder="0" style="display:none;"></iframe>
#             <div id="autoSuggestList2ndKeywordsListSFB" class="suggestionList srch-suggest" style="display:none;">
#               <h5>Suggested Keywords</h5>
#           <ul></ul></div>
#           </div>
#         <div class="auto-suggest-blk location-srch">
#
#
#   <input id="txtLocation" name="txtLocation" type="text" class="location-srch browser-default" value="Enter Location"/><div id="autoSuggestLocation" style="display:none;"><ul></ul></div><iframe id="FrameautoSuggestLocation" style="display:none" frameborder="0"></iframe></div>
#       <div class="srch-select">
#           <select id = "cboWorkExp1" name="cboWorkExp1" class="browser-default">
#
#
#
#                       <option value="-1" >Experience</option>
#
#
#
#                       <option value="0" >Entry Level</option>
#
#
#
#                       <option value="1" >1 year</option>
#
#
#
#                       <option value="2" >2 years</option>
#
#
#
#                       <option value="3" >3 years</option>
#
#
#
#                       <option value="4" >4 years</option>
#
#
#
#                       <option value="5" >5 years</option>
#
#
#
#                       <option value="6" >6 years</option>
#
#
#
#                       <option value="7" >7 years</option>
#
#
#
#                       <option value="8" >8 years</option>
#
#
#
#                       <option value="9" >9 years</option>
#
#
#
#                       <option value="10" >10 years</option>
#
#
#
#                       <option value="11" >11 years</option>
#
#
#
#                       <option value="12" >12 years</option>
#
#
#
#                       <option value="13" >13 years</option>
#
#
#
#                       <option value="14" >14 years</option>
#
#
#
#                       <option value="15" >15 years</option>
#
#
#
#                       <option value="16" >16 years</option>
#
#
#
#                       <option value="17" >17 years</option>
#
#
#
#                       <option value="18" >18 years</option>
#
#
#
#                       <option value="19" >19 years</option>
#
#
#
#                       <option value="20" >20 years</option>
#
#
#
#                       <option value="21" >20+ years</option>
#
#           </select>
#       </div>
#           <button class="waves-effect waves-light btn" value="Search" onclick="javascript:setAClickOnSearch();">Find Jobs</button>
#
#       </form>
#   </div>
# <div id="recentSearchId" class="recent-srchs home-srchptext srch-top-right" style="display: none;"></div>
#
#   <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
#     <div class="upload-res-txt clearfix">
#       <span class="upload-icon"></span>
#       <div class="upload-res-input">
#         <h5>New to Timesjobs?</h5>
#         <label class="upload-res-btn" id="uploadResume_basic">
#           upload your resume
#           <input name="resumeFile_basic" id="resumeFile_basic" size="25" type="file" />
#           </label>
#         <span id="uploadingResume_basic" style="display:none"><img src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif" alt="Uploading Resume"></span>
#         </div>
#       </div>
#   </div>
#
#    </div>
# <script type="text/javascript">
#   var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
# 			jQuery("#txtKeywords").val(text +","+ that);
# 			jQuery("#txtKeywords").focus();
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#   </script>
# 			</div>
#
#
#
#
#
# <script>
# var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
# </script>
#
#
# <script type='text/javascript'>
#
# //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#
# </script>
#
#
# <script type='text/javascript'>
#
# if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
# </script>
#
# <script type="text/javascript">
# 		$(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
# 	</script>
# <script>
# 	jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
# </script>
#
# 				<!-- Header Ends -->
#
# 				<!-- Content Starts   -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="ubility-wrap clearfix">
#     <!--Cluster related page inclusion start here-->
#
# 	<!--Cluster related page inclusion end here-->
#   <section class="ubility-lhs clearfix">
#
# <div id="search-result-cluster" class="inside-lhs">
# 	<div class="wht-bdr-bx tj-cluster">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <h4><i class="material-icons">sort</i>Refined By</h4>
# <!--  <div id="clusterRefineHistoryId"></div>-->
#
#
#
#
#
#
# <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#
#       <li class="tab-exp" id="tab-exp"><a href="#tabexp">Experience</a></li>
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
#
#   <div id="tj-tab-container-clusterId">
#     <div id="clusterDataInitial">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<ul class="collapsible" data-collapsible="expandable">
#
#
#   <li id="tabtc">
#
#
# 	  <div class="collapsible-header active"><h6>Companies</h6></div>
#     <div class="cluster-scroll collapsible-body">
#       <ul>
#         <div id="comp_show">
#
#
#
#
#             <li>
#
#
#
#
#
#
#
#                 <input id="com_0" type="checkbox" name="topCompanies"   onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&refineBy=dateWise&from=undo&actualTxtKeywords=python&searchBy=0&rdoOperator=OR&searchType=personalizedSearch&luceneResultSize=25&postWeek=60&txtKeywords=python&undokey=compCluster&compCluster=nokia+siemens+networks+ltd&gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&refineBy=dateWise&from=undo&actualTxtKeywords=python&searchBy=0&rdoOperator=OR&searchType=personalizedSearch&luceneResultSize=25&postWeek=60&txtKeywords=python&undokey=compCluster&compCluster=nokia+siemens+networks+ltd&gadLink=View Jobs By This Company','Nokia Siemens Networks Ltd');">
# 				<label for="com_0">
#                 <span title="Nokia Siemens Networks Ltd">
#                 Nokia Siemens Networks Ltd
#                 </span> <span class="grey-text">(607)</span></label>
#             </li>
#
#
#
#             <li>
#
#
#
#
#
#
#
# ...
#
#
#
#
# <!-- New google pixel by sokrati -->
# <!-- Global site tag (gtag.js) - Google Ads: 1067146772 -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=AW-1067146772"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-1067146772');
# </script>
#
# <!-- New google pixel by sokrati -->
#
#
#
#
# <script>
# 	var parameter="";
# 	var regFlow="";
# 	var loginFlow="";
# 	var applyFlow="";
#
# 	regFlow="false";
# 	loginFlow="false";
# 	applyFlow="false";
#
# 	if(regFlow=="true")
# 	{
# 		parameter="_registrationFlow";
# 		ajaxController.trackCounter(parameter, "reg_3p9901_exp");
# 	}
# 	else if(loginFlow=="true"){
# 		var login = new RegExp("login.html", "i");
# 		if(!login.test(window.top.location) ){
# 			parameter="_loginFlow";
# 			ajaxController.trackCounter(parameter, "login_3p9901_exp");
# 		}
# 	}
#
# 	if(applyFlow=="true"){
# 		parameter="_applyFlow";
# 		ajaxController.trackCounter(parameter, "apply_3p9901_exp");
# 	}
# </script>
#
#
# <script type="text/javascript" src="//connect.facebook.net/en_US/sdk.js"></script>
#
#
#
# 	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/fb_auto_connect.js?v=7.1.8"></script>
#
#
#
#
#
#
#
#
#
#
# <!-- Columbia AdTech(TIL) Code start Here -->
# <script type='text/javascript'>
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://static.clmbtech.com/ase/2320/34/aa.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# <!-- Columbia AdTech(TIL) Code end Here -->
#
# <script type='text/javascript'>
# 	function freshWidgetCallback(){
# 		FreshWidget.init("", {"queryString": "&widgetType=popup&captcha=yes&searchArea=no", "backgroundImage": "https://www.ceoconnect.in/feedback/images/tj_feedback.gif", "utf8": "?", "widgetType": "popup", "buttonType": "image", "buttonText": "Support", "buttonColor": "black", "buttonBg": "#b8eaff", "alignment": "2", "offset": "145px", "formHeight": "500px", "captcha": "yes", "url": "https://timesjobs.freshdesk.com"} );
# 	}
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://assets.freshdesk.com/widget/freshwidget.js';
#          var x = document.getElementsByTagName('script')[0];
#          // most browsers
# 		s.onload = freshWidgetCallback;
# 		// IE 6 & 7
# 		s.onreadystatechange = function() {
# 			if (this.readyState == 'complete') {
# 				freshWidgetCallback();
# 			}
# 		}
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
#
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1727549374127582'); // Insert your pixel ID here.
# fbq('track', 'PageView');
#
# </script>
# <noscript><img height="1" width="1" style="display:none"
# src="https://www.facebook.com/tr?id=1727549374127582&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Facebook Pixel Code -->
# 				<!-- Footer Ends   -->
#
#
#
#
#
# 	<script type="text/javascript">
#         var GB_ROOT_DIR = "/candidate/greybox/";
#     </script>
#
#
# 	<link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" rel="stylesheet" type="text/css" media="all"/>
#
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.8"></script>
#
#
#
#
# 		<script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
#           <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
#
#
# <script type='text/javascript'>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#
#
# </script>
#
# <noscript>
#   <img src="https://sb.scorecardresearch.com/p?c1=2&c2=6036484&cv=2.0&cj=1" />
# </noscript>
#
# <script type='text/javascript'>
# /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
# </script>
#
# <script type='text/javascript'>
# 	jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
# </script>
# 	<script type="text/javascript">
# 	function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
# 	</script>
#
#
#
#
# <script type="text/javascript">
#
# var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
# </script>
# 	<!--Common Template Included in all files end here  -->
# 	<!--google analytics start-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
# </script>
# 	<!--google analytics ends-->
#
# 		<img src="https://tracking.sokrati.com/site?client_id=60&product_category=Site_Search" height="1" width="1" border="0" alt="" />
#
#
# <script type='text/javascript'>
#
# 	function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# 		</div>
#
# <script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js"></script>
# <div id="light-box-popup" class="modal">
# 	<span class="material-icons close-modal modal-action modal-close">close</span>
# 	<div class="modal-content" id="light-box-popup-content"></div>
# </div>
# <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<!--  ##########################  JobBuzz Ads  ################## -->
#
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"applicationID":"57254935","applicationTime":803,"beacon":"bam.nr-data.net","queueTime":0,"licenseKey":"2aa1afabd7","transactionName":"NVRSNRAAVhVZUxIMXgweejIyTm8jeh0vK3dNW0MRTRRLB1pZCgxFGx5EBA8RVAdMVUkGUAxVWQUDFV01XVEUBlkQVEMUDhVsA1VACgRFBx9aEhI=","agent":"","errorBeacon":"bam.nr-data.net"}</script></body>
# </html>
